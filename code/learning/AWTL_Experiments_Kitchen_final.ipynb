# %% [markdown]
# ### Imports and settings

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
import al_learning as alle
#import atl_learning as atl
import awtl_learning as awtl
#import atl_weighted_learning as awtl_rf
import warnings
#from sklearn.exceptions import UndefinedMetricWarning
#warnings.filterwarnings(action='ignore', category=UndefinedMetricWarning)
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

import matplotlib.pyplot as plt
import seaborn as sns
#import itertools
#import math
from matplotlib import style
style.use('seaborn-white')
#sns.set_context("paper")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 3,"font.size":19, "axes.labelsize":19,
    "axes.titlesize":19})

import sys
sys.path.append('../')
import support_utils as sup
import al_plot_utils as alut
import data_explore_utils as dex
import display_utils as dut

# %% [markdown]
# ### Import Candsets Supervised & Unsupervised Results etc.

# %%
# see DocString of readDataInDictionary() function for information

# ***CHANGE THE FOLLOWING VARIABLES IF STH CHANGED***
path_to_directory = '../../candsets/kitchen/'
pattern_of_filename = 'candset_feature_(.{3,5}_.{2,4})'
sep = ','
# ***********************************************

candsets = sup.readDataInDictionary(path_to_directory,pattern_of_filename,sep)

# %%
candsets.keys()
# Out:
# dict_keys(['katom_cdi', 'rewo_cdi', 'katom_rewo'])

# %%
# see DocString of readDataInDictionary() function for information

# ***CHANGE THE FOLLOWING VARIABLES IF STH CHANGED***
path_to_directory = '../../candsets/kitchen/'
pattern_of_filename = 'candset_feature_(.{3,5}_.{2,4})_train'
sep = ','
# ***********************************************

candsets_train = sup.readDataInDictionary(path_to_directory,pattern_of_filename,sep)

# %%
# see DocString of readDataInDictionary() function for information

# ***CHANGE THE FOLLOWING VARIABLES IF STH CHANGED***
path_to_directory = '../../candsets/kitchen/'
pattern_of_filename = 'candset_feature_(.{3,5}_.{2,4})_test'
sep = ','
# ***********************************************

candsets_test = sup.readDataInDictionary(path_to_directory,pattern_of_filename,sep)

# %% [markdown]
# #### Feature Sets and Supervised and Unsupervised Results

# %%
all_feature = ['finish_lev_sim', 'finish_jac_q3_sim', 'finish_jac_an_sim',
       'finish_rel_jac_an_sim', 'finish_containment_sim', 'finish_exact_sim',
       'shape_lev_sim', 'shape_jac_q3_sim', 'shape_jac_an_sim',
       'shape_rel_jac_an_sim', 'shape_containment_sim', 'shape_exact_sim',
       'color_lev_sim', 'color_jac_q3_sim', 'color_jac_an_sim',
       'color_rel_jac_an_sim', 'color_containment_sim', 'color_exact_sim',
       'base_lev_sim', 'base_jac_q3_sim', 'base_jac_an_sim',
       'base_rel_jac_an_sim', 'base_containment_sim', 'base_exact_sim',
       'style_cosine_tfidf_sim', 'style_lev_sim', 'style_jac_q3_sim',
       'style_jac_an_sim', 'style_rel_jac_an_sim', 'style_containment_sim',
       'style_exact_sim', 'height_lev_sim', 'height_jac_q3_sim',
       'height_jac_an_sim', 'height_rel_jac_an_sim', 'height_containment_sim',
       'height_exact_sim', 'category_lev_sim', 'category_jac_q3_sim',
       'category_jac_an_sim', 'category_rel_jac_an_sim',
       'category_containment_sim', 'category_exact_sim',
       'title_cosine_tfidf_sim', 'title_lev_sim', 'title_jac_q3_sim',
       'title_jac_an_sim', 'title_rel_jac_an_sim', 'title_containment_sim',
       'title_exact_sim', 'capacity_lev_sim', 'capacity_jac_q3_sim',
       'capacity_jac_an_sim', 'capacity_rel_jac_an_sim',
       'capacity_containment_sim', 'capacity_exact_sim', 'material_lev_sim',
       'material_jac_q3_sim', 'material_jac_an_sim', 'material_rel_jac_an_sim',
       'material_containment_sim', 'material_exact_sim', 'brand_lev_sim',
       'brand_jac_q3_sim', 'brand_jac_an_sim', 'brand_rel_jac_an_sim',
       'brand_containment_sim', 'brand_exact_sim', 'product_type_lev_sim',
       'product_type_jac_q3_sim', 'product_type_jac_an_sim',
       'product_type_rel_jac_an_sim', 'product_type_containment_sim',
       'product_type_exact_sim']

# %%
len(all_feature) == len(candsets['katom_cdi'].columns.drop(['ids','label']))
# Out:
# True

# %%
dex.plotDensityAttributesHeatmap(candsets)

# %%
# dense features for all combinations

# features excluded where the attribute has a very low density (<3%) for at 
# least one dataset that is involved either as source or target in the TL setting
rc_cdi_katom_rewo = ['finish_lev_sim', 'finish_jac_q3_sim',
       'finish_jac_an_sim', 'finish_rel_jac_an_sim', 'finish_containment_sim',
       'finish_exact_sim', 'color_lev_sim', 'color_jac_q3_sim',
       'color_jac_an_sim', 'color_rel_jac_an_sim', 'color_containment_sim',
       'color_exact_sim', 'base_lev_sim', 'base_jac_q3_sim', 'base_jac_an_sim',
       'base_rel_jac_an_sim', 'base_containment_sim', 'base_exact_sim',
       'style_cosine_tfidf_sim', 'style_lev_sim', 'style_jac_q3_sim',
       'style_jac_an_sim', 'style_rel_jac_an_sim', 'style_containment_sim',
       'style_exact_sim', 'height_lev_sim', 'height_jac_q3_sim',
       'height_jac_an_sim', 'height_rel_jac_an_sim', 'height_containment_sim',
       'height_exact_sim', 'title_cosine_tfidf_sim', 'title_lev_sim', 'title_jac_q3_sim',
       'title_jac_an_sim', 'title_rel_jac_an_sim', 'title_containment_sim',
       'title_exact_sim', 'capacity_lev_sim', 'capacity_jac_q3_sim',
       'capacity_jac_an_sim', 'capacity_rel_jac_an_sim',
       'capacity_containment_sim', 'capacity_exact_sim', 'material_lev_sim',
       'material_jac_q3_sim', 'material_jac_an_sim', 'material_rel_jac_an_sim',
       'material_containment_sim', 'material_exact_sim', 'brand_lev_sim',
       'brand_jac_q3_sim', 'brand_jac_an_sim', 'brand_rel_jac_an_sim',
       'brand_containment_sim', 'brand_exact_sim', 'product_type_lev_sim',
       'product_type_jac_q3_sim', 'product_type_jac_an_sim',
       'product_type_rel_jac_an_sim', 'product_type_containment_sim',
       'product_type_exact_sim']

# assign the different feature sets (different dense features depending on combination)
dense_features_dict = {'cdi_katom_rewo':rc_cdi_katom_rewo}

# %%
# ***CHANGE THE FOLLOWING VARIABLES IF STH CHANGED***
path_to_directory = '../../results/benchmarks/'
supervised_results = 'kitchen_candsets_super_results'
unsupervised_results = 'kitchen_candsets_unsuper_results'

# we use the same random_state for all experiments
random_state = 42
# assign which sklearn estimators to use for the TL Experiment
#estimators_tl = {'logreg':LogisticRegression(random_state=random_state,solver='liblinear',max_iter=1000),
#                 'dectree':DecisionTreeClassifier(random_state=random_state),
#                 'randforest':RandomForestClassifier(random_state=random_state,n_estimators=10),
#                 'xgb':xgb.XGBClassifier(random_state=random_state,objective="binary:logistic"),
#                 'svm':LinearSVC(random_state=random_state,dual=False),
#                 #'svm':SVC(random_state=random_state,kernel='linear'),
#                 'logregcv':LogisticRegressionCV(random_state=random_state,cv=5,solver='liblinear',max_iter=1000)}

# %% [markdown]
# #### Import Passive Learning (Supervised) Results

# %%
candsets_super_results = sup.importJSONFileInDict(path_to_directory+supervised_results)

# %%
# the function returnDFWithSuper() returns a dataframe with the supervised results and displays 
# a highlighted dataframe in the output where the best result per candidate set is highlighted.
df_super = dut.returnDFWithSuper(candsets_super_results)
# Out:
# <style  type="text/css" >
#     #T_64c5f916_d630_11ea_928d_d1854d4f2765 th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col5 {
#             background-color:  #FBFF75;
#         }    #T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col5 {
#             background-color:  #FBFF75;
#         }    #T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col5 {
#             background-color:  #FBFF75;
#         }</style><table id="T_64c5f916_d630_11ea_928d_d1854d4f2765" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >logreg</th>        <th class="col_heading level0 col1" >logregcv</th>        <th class="col_heading level0 col2" >svm</th>        <th class="col_heading level0 col3" >dectree</th>        <th class="col_heading level0 col4" >randforest</th>        <th class="col_heading level0 col5" >xgb</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64c5f916_d630_11ea_928d_d1854d4f2765level0_row0" class="row_heading level0 row0" >katom_cdi</th>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col0" class="data row0 col0" >0.815</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col1" class="data row0 col1" >0.875</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col2" class="data row0 col2" >0.853</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col3" class="data row0 col3" >0.848</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col4" class="data row0 col4" >0.904</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row0_col5" class="data row0 col5" >0.917</td>
#             </tr>
#             <tr>
#                         <th id="T_64c5f916_d630_11ea_928d_d1854d4f2765level0_row1" class="row_heading level0 row1" >rewo_cdi</th>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col0" class="data row1 col0" >0.727</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col1" class="data row1 col1" >0.729</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col2" class="data row1 col2" >0.727</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col3" class="data row1 col3" >0.786</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col4" class="data row1 col4" >0.822</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row1_col5" class="data row1 col5" >0.851</td>
#             </tr>
#             <tr>
#                         <th id="T_64c5f916_d630_11ea_928d_d1854d4f2765level0_row2" class="row_heading level0 row2" >katom_rewo</th>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col0" class="data row2 col0" >0.747</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col1" class="data row2 col1" >0.748</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col2" class="data row2 col2" >0.743</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col3" class="data row2 col3" >0.768</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col4" class="data row2 col4" >0.810</td>
#                         <td id="T_64c5f916_d630_11ea_928d_d1854d4f2765row2_col5" class="data row2 col5" >0.839</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Import Unsupervised Results

# %%
candsets_unsuper_results = sup.importJSONFileInDict(path_to_directory+unsupervised_results)

# %%
# the function returnDFWithUnsuper() returns a dataframe with the unsupervised results of the 
# elbow threshold method on the weighted sum of similarities and displays 
# a highlighted dataframe in the output where the best result per candidate set is highlighted.
df_unsuper = dut.returnDFWithUnsuper(candsets_unsuper_results)
# Out:
# <style  type="text/css" >
#     #T_65b47bae_d630_11ea_928d_d1854d4f2765 th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_65b47bae_d630_11ea_928d_d1854d4f2765row1_col0 {
#             background-color:  #FBFF75;
#         }</style><table id="T_65b47bae_d630_11ea_928d_d1854d4f2765" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >F1 score</th>        <th class="col_heading level0 col1" >Elbow Threshold</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65b47bae_d630_11ea_928d_d1854d4f2765level0_row0" class="row_heading level0 row0" >katom_cdi</th>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row0_col0" class="data row0 col0" >0.648</td>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row0_col1" class="data row0 col1" >0.486</td>
#             </tr>
#             <tr>
#                         <th id="T_65b47bae_d630_11ea_928d_d1854d4f2765level0_row1" class="row_heading level0 row1" >rewo_cdi</th>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row1_col0" class="data row1 col0" >0.652</td>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row1_col1" class="data row1 col1" >0.269</td>
#             </tr>
#             <tr>
#                         <th id="T_65b47bae_d630_11ea_928d_d1854d4f2765level0_row2" class="row_heading level0 row2" >katom_rewo</th>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row2_col0" class="data row2 col0" >0.196</td>
#                         <td id="T_65b47bae_d630_11ea_928d_d1854d4f2765row2_col1" class="data row2 col1" >0.664</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Active Learning (no transfer) as Baseline!

# %% [markdown]
# #### Run Experiments

# %%
import warnings
#from sklearn.exceptions import UndefinedMetricWarning
from sklearn.exceptions import ConvergenceWarning
#warnings.filterwarnings(action='ignore', category=UndefinedMetricWarning)
warnings.filterwarnings(action='ignore', category=ConvergenceWarning)
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# ***CHANGE THE FOLLOWING VARIABLES IF STH CHANGED***
query_strategies = ['lr_lsvc_rf_dt','random']
estimator_names = ['lr','xgb','rf']
feature = all_feature
n_labeled = 2 #initially labled 
quota = 100

# ***********************************************

al_results = alle.al_all(candsets_train,candsets_test,feature,estimator_names,query_strategies,
                         n_labeled,quota,disagreement='vote',n=5)
# Out:
# Start with AL using different settings for katom_cdi
# Start with Estimator: lr
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 20.87 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 20.58 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 19.97 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 19.76 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 19.93 seconds
# Start with Query Strategy: random
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 1.31 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 1.27 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 1.26 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 1.41 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 1.23 seconds
# Start with Estimator: xgb
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 29.77 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 30.08 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 30.15 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 30.82 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 30.76 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 11.46 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 10.62 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 11.86 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 11.79 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 9.91 seconds
# Start with Estimator: rf
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 38.21 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 39.00 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 38.91 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 40.06 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 38.84 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset katom_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 21.37 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 20.02 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 22.13 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 22.08 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 21.48 seconds
# Start with AL using different settings for rewo_cdi
# Start with Estimator: lr
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.17 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.83 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.44 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.56 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.78 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 3.96 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 3.75 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 3.75 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 3.73 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 3.78 seconds
# Start with Estimator: xgb
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 34.29 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 35.95 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 33.38 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 34.35 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 32.99 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.95 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.27 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 15.44 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 17.57 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 18.94 seconds
# Start with Estimator: rf
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 44.04 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 44.12 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 43.92 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 45.03 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 45.33 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 23.75 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 23.97 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 23.47 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 23.91 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 24.40 seconds
# Start with AL using different settings for katom_rewo
# Start with Estimator: lr
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.14 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.23 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 24.90 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 25.82 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.43 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 4.13 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 4.22 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 4.13 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 4.17 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 4.38 seconds
# Start with Estimator: xgb
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 33.45 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 36.52 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 35.14 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |█-------------------------------------------------| 3.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 4.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██------------------------------------------------| 5.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |███-----------------------------------------------| 6.1% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 35.76 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 34.39 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/xgboost/sklearn.py:695: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.41 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.52 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 18.02 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.71 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 16.62 seconds
# Start with Estimator: rf
# Start with Query Strategy: lr_lsvc_rf_dt
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 48.08 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 47.27 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 47.32 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 48.85 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 49.93 seconds
# Start with Query Strategy: random
# Starting AL Experiments (no transfer!) for candset katom_rewo
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.36 seconds
# 2. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 27.11 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.40 seconds
# 4. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.71 seconds
# 5. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 26.65 seconds
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sup.saveResultsToJSON(al_results,'../../results/benchmarks/kitchen_al_results')
# Out:
# Saved in ../../results/benchmarks/home_al_results.json

# %% [markdown]
# #### Import Experiment Results

# %%
al_results = sup.importJSONFileInDict('../../results/benchmarks/kitchen_al_results')

# %% [markdown]
# ### Active Transfer Learning

# %% [markdown]
# #### Run Experiments

# %%
query_strategies = ['lr_lsvc_rf_dt','random']
estimator_names = ['rf']
weighting = [None,'nn','lr_predict_proba']
quota = 100
feature = all_feature
# *******************************

awtl_single(candsets,candsets_train,candsets_test,source_name,target_name,feature,estimators,query_strategies,
                                           quota,weighting=[None],disagreement='vote',n=5)

# %% [markdown]
# ##### All

# %%
# CAUTION: Takes long to compute!
query_strategies = ['lr_lsvc_rf_dt','random']
estimator_names = ['rf']
weighting = [None,'nn','lr_predict_proba']
quota = 100
feature = all_feature
# *******************************

awtl_results_dense = awtl.awtl_all_combinations(candsets,candsets_train,candsets_test,
                                                estimator_names,query_strategies,quota,
                                                feature,dense_features_dict,weighting,
                                                disagreement='vote',n=5,switch_roles=True)
# Out:
# Start with ATL using different settings for source katom_cdi and target rewo_cdi
# Start with Estimator: rf
# Start with Query Strategy: lr_lsvc_rf_dt
# Start with Weighting Strategy: None
# No Unsupervised Domain Adaptation performed
# Starting ATL Experiments (WITH transfer!) source katom_cdi and target rewo_cdi
# 1. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 3.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 4.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 5.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 6.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 7.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 8.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 9.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 10.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 11.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 12.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 13.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 14.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 15.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 16.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 17.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 6.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 7.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 8.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 9.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 10.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 11.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 12.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 13.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 14.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 15.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 16.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 17.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 18.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 19.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 20.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 21.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 22.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 23.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 24.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 25.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 26.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 27.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 28.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 29.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 30.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 31.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 32.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 33.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 34.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 35.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 36.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 37.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 38.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 39.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 40.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 41.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████-----------------------------| 42.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████-----------------------------| 43.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████----------------------------| 44.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████----------------------------| 45.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████---------------------------| 46.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████---------------------------| 47.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████--------------------------| 48.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████--------------------------| 49.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████-------------------------| 50.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████-------------------------| 51.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████------------------------| 52.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████------------------------| 53.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████-----------------------| 54.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████-----------------------| 55.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████----------------------| 56.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████----------------------| 57.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████---------------------| 58.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████---------------------| 59.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████--------------------| 60.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████--------------------| 61.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████-------------------| 62.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████-------------------| 63.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████------------------| 64.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████------------------| 65.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████-----------------| 66.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████-----------------| 67.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████----------------| 68.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████----------------| 69.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████---------------| 70.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████---------------| 71.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████--------------| 72.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████--------------| 73.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████-------------| 74.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████-------------| 75.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████------------| 76.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████------------| 77.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████-----------| 78.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████-----------| 79.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████----------| 80.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████----------| 81.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████---------| 82.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████---------| 83.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████████--------| 84.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████████--------| 85.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████████-------| 86.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████████-------| 87.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████████------| 88.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████████------| 89.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████████-----| 90.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████████-----| 91.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████████████----| 92.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████████████----| 93.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████████████---| 94.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████████████████████████████---| 95.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████████████--| 96.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████████████████████████████--| 97.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████████████-| 98.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████████████████████████████-| 99.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Runtime: 121.52 seconds
# 3. Run of 5
# Initialize Learning Model
# Initialize Query Strategy
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 3.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 4.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 5.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 6.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 7.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 8.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 9.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 10.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 11.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 12.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 13.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 14.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 15.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 16.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 17.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 18.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 19.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 20.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 21.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 22.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 23.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 24.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 25.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 26.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 27.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 28.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 29.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 30.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 31.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 32.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 33.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 34.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 35.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 36.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 37.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 38.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 39.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 40.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 41.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████-----------------------------| 42.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ...
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 0.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |--------------------------------------------------| 1.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 2.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█-------------------------------------------------| 3.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 4.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██------------------------------------------------| 5.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 6.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███-----------------------------------------------| 7.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 8.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████----------------------------------------------| 9.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 10.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████---------------------------------------------| 11.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 12.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████--------------------------------------------| 13.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 14.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████-------------------------------------------| 15.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 16.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████------------------------------------------| 17.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 18.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████-----------------------------------------| 19.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 20.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████----------------------------------------| 21.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 22.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████---------------------------------------| 23.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 24.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████--------------------------------------| 25.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 26.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████-------------------------------------| 27.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 28.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████------------------------------------| 29.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 30.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████-----------------------------------| 31.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 32.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████----------------------------------| 33.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 34.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████---------------------------------| 35.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 36.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████--------------------------------| 37.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 38.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████-------------------------------| 39.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 40.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████------------------------------| 41.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████-----------------------------| 42.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████-----------------------------| 43.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████----------------------------| 44.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████----------------------------| 45.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████---------------------------| 46.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |███████████████████████---------------------------| 47.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████--------------------------| 48.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |████████████████████████--------------------------| 49.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████-------------------------| 50.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |█████████████████████████-------------------------| 51.0% Complete
# /home/debian/anaconda3/envs/atl_da/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Progress: |██████████████████████████------------------------| 52.0% Complete

# %%
awtl_results_dense.keys()
# Out:
# dict_keys(['katom_cdi_rewo_cdi', 'rewo_cdi_katom_cdi', 'katom_cdi_katom_rewo', 'katom_rewo_katom_cdi', 'rewo_cdi_katom_rewo', 'katom_rewo_rewo_cdi'])

# %%
#sup.saveResultsToJSON(awtl_results_dense,'../../results/awtl/kitchen_awtl_results_dense')

# %% [markdown]
# #### Import AWTL Results

# %%
awtl_results = sup.importJSONFileInDict('../../results/awtl/kitchen_awtl_results_dense')

# %%
selected_weighting = 'no_weighting'
selected_qs = None
max_quota = 100

df_awtl_no_weighting = dut.createDFwithAlandAWTLResultsMoreItersUpToMaxQuota(awtl_results,al_results,
                                                                             selected_weighting,
                                                                             candsets_super_results,
                                                                             selected_qs,
                                                                             max_quota,filename='../../results/awtl/kitchen_awtl_results_nw')
# Out:
# Weighting: no_weighting and Query Strategy: None
# <style  type="text/css" >
#     #T_7b8c361a_c8f2_11ea_b845_5f125640553a th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow0_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow0_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow0_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow0_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow0_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow1_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow2_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow2_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow2_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow3_col24 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow4_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col9 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col18 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col20 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_7b8c361a_c8f2_11ea_b845_5f125640553arow5_col24 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }</style><table id="T_7b8c361a_c8f2_11ea_b845_5f125640553a" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Estimator</th>        <th class="col_heading level0 col0" colspan=26>rf</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >QS</th>        <th class="col_heading level1 col0" colspan=13>lr_lsvc_rf_dt</th>        <th class="col_heading level1 col13" colspan=13>random</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level2" >Iteration</th>        <th class="col_heading level2 col0" colspan=2>2nd</th>        <th class="col_heading level2 col2" colspan=2>10th</th>        <th class="col_heading level2 col4" colspan=2>20th</th>        <th class="col_heading level2 col6" colspan=2>30th</th>        <th class="col_heading level2 col8" colspan=2>50th</th>        <th class="col_heading level2 col10" colspan=2>100th</th>        <th class="col_heading level2 col12" >all</th>        <th class="col_heading level2 col13" colspan=2>2nd</th>        <th class="col_heading level2 col15" colspan=2>10th</th>        <th class="col_heading level2 col17" colspan=2>20th</th>        <th class="col_heading level2 col19" colspan=2>30th</th>        <th class="col_heading level2 col21" colspan=2>50th</th>        <th class="col_heading level2 col23" colspan=2>100th</th>        <th class="col_heading level2 col25" >all</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level3" >Results</th>        <th class="col_heading level3 col0" >ATL</th>        <th class="col_heading level3 col1" >AL</th>        <th class="col_heading level3 col2" >ATL</th>        <th class="col_heading level3 col3" >AL</th>        <th class="col_heading level3 col4" >ATL</th>        <th class="col_heading level3 col5" >AL</th>        <th class="col_heading level3 col6" >ATL</th>        <th class="col_heading level3 col7" >AL</th>        <th class="col_heading level3 col8" >ATL</th>        <th class="col_heading level3 col9" >AL</th>        <th class="col_heading level3 col10" >ATL</th>        <th class="col_heading level3 col11" >AL</th>        <th class="col_heading level3 col12" >Tar_sup</th>        <th class="col_heading level3 col13" >ATL</th>        <th class="col_heading level3 col14" >AL</th>        <th class="col_heading level3 col15" >ATL</th>        <th class="col_heading level3 col16" >AL</th>        <th class="col_heading level3 col17" >ATL</th>        <th class="col_heading level3 col18" >AL</th>        <th class="col_heading level3 col19" >ATL</th>        <th class="col_heading level3 col20" >AL</th>        <th class="col_heading level3 col21" >ATL</th>        <th class="col_heading level3 col22" >AL</th>        <th class="col_heading level3 col23" >ATL</th>        <th class="col_heading level3 col24" >AL</th>        <th class="col_heading level3 col25" >Tar_sup</th>    </tr>    <tr>        <th class="index_name level0" >Source</th>        <th class="index_name level1" >Target</th>        <th clas

# %%
selected_weighting = 'nn'
selected_qs = None
max_quota = 100

df_awtl_nn = dut.createDFwithAlandAWTLResultsMoreItersUpToMaxQuota(awtl_results,al_results,
                                                                   selected_weighting,candsets_super_results,
                                                                   selected_qs,max_quota,
                                                                   filename='../../results/awtl/kitchen_awtl_results_nn')
# Out:
# Weighting: nn and Query Strategy: None
# <style  type="text/css" >
#     #T_847d5754_c8f2_11ea_b845_5f125640553a th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_847d5754_c8f2_11ea_b845_5f125640553arow0_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow0_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow0_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow0_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow0_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow1_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow1_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow1_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow2_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow2_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow2_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow3_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow4_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col9 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_847d5754_c8f2_11ea_b845_5f125640553arow5_col24 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }</style><table id="T_847d5754_c8f2_11ea_b845_5f125640553a" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Estimator</th>        <th class="col_heading level0 col0" colspan=26>rf</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >QS</th>        <th class="col_heading level1 col0" colspan=13>lr_lsvc_rf_dt</th>        <th class="col_heading level1 col13" colspan=13>random</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level2" >Iteration</th>        <th class="col_heading level2 col0" colspan=2>2nd</th>        <th class="col_heading level2 col2" colspan=2>10th</th>        <th class="col_heading level2 col4" colspan=2>20th</th>        <th class="col_heading level2 col6" colspan=2>30th</th>        <th class="col_heading level2 col8" colspan=2>50th</th>        <th class="col_heading level2 col10" colspan=2>100th</th>        <th class="col_heading level2 col12" >all</th>        <th class="col_heading level2 col13" colspan=2>2nd</th>        <th class="col_heading level2 col15" colspan=2>10th</th>        <th class="col_heading level2 col17" colspan=2>20th</th>        <th class="col_heading level2 col19" colspan=2>30th</th>        <th class="col_heading level2 col21" colspan=2>50th</th>        <th class="col_heading level2 col23" colspan=2>100th</th>        <th class="col_heading level2 col25" >all</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level3" >Results</th>        <th class="col_heading level3 col0" >ATL</th>        <th class="col_heading level3 col1" >AL</th>        <th class="col_heading level3 col2" >ATL</th>        <th class="col_heading level3 col3" >AL</th>        <th class="col_heading level3 col4" >ATL</th>        <th class="col_heading level3 col5" >AL</th>        <th class="col_heading level3 col6" >ATL</th>        <th class="col_heading level3 col7" >AL</th>        <th class="col_heading level3 col8" >ATL</th>        <th class="col_heading level3 col9" >AL</th>        <th class="col_heading level3 col10" >ATL</th>        <th class="col_heading level3 col11" >AL</th>        <th class="col_heading level3 col12" >Tar_sup</th>        <th class="col_heading level3 col13" >ATL</th>        <th class="col_heading level3 col14" >AL</th>        <th class="col_heading level3 col15" >ATL</th>        <th class="col_heading level3 col16" >AL</th>        <th class="col_heading level3 col17" >ATL</th>        <th class="col_heading level3 col18" >AL</th>        <th class="col_heading level3 col19" >ATL</th>        <th class="col_heading level3 col20" >AL</th>        <th class="col_heading level3 col21" >ATL</th>        <th class="col_heading level3 col22" >AL</th>        <th class="col_heading level3 col23" >ATL</th>        <th class="col_heading level3 col24" >AL</th>        <th class="col_heading level3 col25" >Tar_sup</th>    </tr>    <tr>        <th class="index_name level0" >Source</th>        <th class="index_name level1" >Target</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %%
selected_weighting = 'lr_predict_proba'
selected_qs = None
max_quota = 100

df_awtl_lprob = dut.createDFwithAlandAWTLResultsMoreItersUpToMaxQuota(awtl_results,al_results,
                                                                      selected_weighting,candsets_super_results,
                                                                      selected_qs,max_quota,
                                                                      filename='../../results/awtl/kitchen_awtl_results_lprob')
# Out:
# Weighting: lr_predict_proba and Query Strategy: None
# <style  type="text/css" >
#     #T_8da87e1c_c8f2_11ea_b845_5f125640553a th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow0_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow1_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow1_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow1_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow1_col20 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow1_col22 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow2_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow3_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow3_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow4_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow4_col8 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow4_col10 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col0 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col2 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col4 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col6 {
#             background-color: #FFA500;
#             : ;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col9 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col11 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col18 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col20 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col22 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }    #T_8da87e1c_c8f2_11ea_b845_5f125640553arow5_col24 {
#             : ;
#             background-color:  #FF7070;
#             : ;
#         }</style><table id="T_8da87e1c_c8f2_11ea_b845_5f125640553a" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Estimator</th>        <th class="col_heading level0 col0" colspan=26>rf</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >QS</th>        <th class="col_heading level1 col0" colspan=13>lr_lsvc_rf_dt</th>        <th class="col_heading level1 col13" colspan=13>random</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level2" >Iteration</th>        <th class="col_heading level2 col0" colspan=2>2nd</th>        <th class="col_heading level2 col2" colspan=2>10th</th>        <th class="col_heading level2 col4" colspan=2>20th</th>        <th class="col_heading level2 col6" colspan=2>30th</th>        <th class="col_heading level2 col8" colspan=2>50th</th>        <th class="col_heading level2 col10" colspan=2>100th</th>        <th class="col_heading level2 col12" >all</th>        <th class="col_heading level2 col13" colspan=2>2nd</th>        <th class="col_heading level2 col15" colspan=2>10th</th>        <th class="col_heading level2 col17" colspan=2>20th</th>        <th class="col_heading level2 col19" colspan=2>30th</th>        <th class="col_heading level2 col21" colspan=2>50th</th>        <th class="col_heading level2 col23" colspan=2>100th</th>        <th class="col_heading level2 col25" >all</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level3" >Results</th>        <th class="col_heading level3 col0" >ATL</th>        <th class="col_heading level3 col1" >AL</th>        <th class="col_heading level3 col2" >ATL</th>        <th class="col_heading level3 col3" >AL</th>        <th class="col_heading level3 col4" >ATL</th>        <th class="col_heading level3 col5" >AL</th>        <th class="col_heading level3 col6" >ATL</th>        <th class="col_heading level3 col7" >AL</th>        <th class="col_heading level3 col8" >ATL</th>        <th class="col_heading level3 col9" >AL</th>        <th class="col_heading level3 col10" >ATL</th>        <th class="col_heading level3 col11" >AL</th>        <th class="col_heading level3 col12" >Tar_sup</th>        <th class="col_heading level3 col13" >ATL</th>        <th class="col_heading level3 col14" >AL</th>        <th class="col_heading level3 col15" >ATL</th>        <th class="col_heading level3 col16" >AL</th>        <th class="col_heading level3 col17" >ATL</th>        <th class="col_heading level3 col18" >AL</th>        <th class="col_heading level3 col19" >ATL</th>        <th class="col_heading level3 col20" >AL</th>        <th class="col_heading level3 col21" >ATL</th>        <th class="col_heading level3 col22" >AL</th>        <th class="col_heading level3 col23" >ATL</th>        <th class="col_heading level3 col24" >AL</th>        <th class="col_heading level3 col25" >Tar_sup</th>    </tr>    <tr>        <th class="index_name level0" >Source</th>        <th class="index_name level1" >Target</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %%
selected_qs = 'lr_lsvc_rf_dt'
max_quota = 100

df_no_weighting_nn_lprob_compared = dut.createDFwithAlandAWTLResultsToCompareDA(awtl_results,al_results,
                                                                                candsets_super_results,
                                                                                selected_qs,max_quota,
                                                                                filename='../../results/awtl/kitchen_awtl_nw_nn_lprob')
# Out:
# All ATL results with no_weighting and nn as well as lr_predict_proba (lp) and Query Strategy: lr_lsvc_rf_dt
# <style  type="text/css" >
#     #T_bd80a830_c8f2_11ea_b845_5f125640553a th {
#           border-style: solid;
#           border-color: #D3D3D3;
#           vertical-align: top;
#           text-align: center;
#     }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow0_col0 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow0_col5 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow0_col9 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow0_col13 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow1_col2 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow1_col5 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow1_col9 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow1_col13 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow2_col0 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow2_col5 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow2_col9 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow2_col13 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow3_col0 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow3_col6 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow3_col9 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow3_col14 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow4_col2 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow4_col5 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow4_col8 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow4_col13 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col1 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col5 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col9 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             : ;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col11 {
#             : ;
#             : ;
#             : ;
#             background-color:  #FF7070;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col13 {
#             color: #000000;
#             background-color: rgba(51, 204, 51, .3);
#             background-color:  yellow;
#             : ;
#             : ;
#             : ;
#             : ;
#         }    #T_bd80a830_c8f2_11ea_b845_5f125640553arow5_col15 {
#             : ;
#             : ;
#             : ;
#             background-color:  #FF7070;
#         }</style><table id="T_bd80a830_c8f2_11ea_b845_5f125640553a" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Estimator</th>        <th class="col_heading level0 col0" colspan=17>rf</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >QS</th>        <th class="col_heading level1 col0" colspan=17>lr_lsvc_rf_dt</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level2" >Iteration</th>        <th class="col_heading level2 col0" colspan=4>2nd</th>        <th class="col_heading level2 col4" colspan=4>20th</th>        <th class="col_heading level2 col8" colspan=4>50th</th>        <th class="col_heading level2 col12" colspan=4>100th</th>        <th class="col_heading level2 col16" >all</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level3" >Results</th>        <th class="col_heading level3 col0" >ATL</th>        <th class="col_heading level3 col1" >_NN</th>        <th class="col_heading level3 col2" >_LP</th>        <th class="col_heading level3 col3" >AL</th>        <th class="col_heading level3 col4" >ATL</th>        <th class="col_heading level3 col5" >_NN</th>        <th class="col_heading level3 col6" >_LP</th>        <th class="col_heading level3 col7" >AL</th>        <th class="col_heading level3 col8" >ATL</th>        <th class="col_heading level3 col9" >_NN</th>        <th class="col_heading level3 col10" >_LP</th>        <th class="col_heading level3 col11" >AL</th>        <th class="col_heading level3 col12" >ATL</th>        <th class="col_heading level3 col13" >_NN</th>        <th class="col_heading level3 col14" >_LP</th>        <th class="col_heading level3 col15" >AL</th>        <th class="col_heading level3 col16" >Tar_sup</th>    </tr>    <tr>        <th class="index_name level0" >Source</th>        <th class="index_name level1" >Target</th>        <th class="bl

# %% [markdown]
# # Plot AWTL Results

# %%
# ***CHANGE THE FOLLOWING VARIABLES AS DESIRED***
source_name = 'rewo_cdi'
target_name = 'katom_cdi'
selected_estimator = ['rf']  # None means all! ['lr'] or ['xgb'] or ['lr','xgb']
selected_qs = ['lr_lsvc_rf_dt']  # None means all! ['lr_lsvc_rf_dt','random']
al_also = al_results   # None means only ATL Results are plotted. If al_also = al_results then also al results
quota = 100
n = 5
selected_weights = None
#awtl_results = awtl_results_dense
# ***********************************************

dut.plotAWTLResults(awtl_results,source_name,target_name,quota,candsets,candsets_super_results,n,
                    selected_estimator,al_also,selected_qs,selected_weights,errorbars=False,ylim=None,
                    info_text=False,path_for_output='../../results/graphics/')

# %%
# ***CHANGE THE FOLLOWING VARIABLES AS DESIRED***
source_name = 'rewo_cdi'
target_name = 'katom_cdi'
selected_estimator = ['rf']  # None means all! ['lr'] or ['xgb'] or ['lr','xgb']
selected_qs = ['lr_lsvc_rf_dt']  # None means all! ['lr_lsvc_rf_dt','random']
al_also = al_results   # None means only ATL Results are plotted. If al_also = al_results then also al results
quota = 100
n = 5
selected_weights = None
#awtl_results = awtl_results_dense
# ***********************************************

dut.plotAWTLResults(awtl_results,source_name,target_name,quota,candsets,candsets_super_results,n,
                    selected_estimator,al_also,selected_qs,selected_weights,errorbars=False,ylim=None,
                    info_text=False,path_for_output='../../results/graphics/')

# %%
# ***CHANGE THE FOLLOWING VARIABLES AS DESIRED***
source_name = 'rewo_cdi'
target_name = 'katom_cdi'
selected_estimator = ['rf']  # None means all! ['lr'] or ['xgb'] or ['lr','xgb']
selected_qs = ['lr_lsvc_rf_dt']  # None means all! ['lr_lsvc_rf_dt','random']
al_also = al_results   # None means only ATL Results are plotted. If al_also = al_results then also al results
quota = 100
n = 5
selected_weights = ['nn']
errorbars = True
#awtl_results = awtl_results_dense
# ***********************************************

dut.plotAWTLResults(awtl_results,source_name,target_name,quota,candsets,candsets_super_results,n,
                    selected_estimator,al_also,selected_qs,selected_weights,errorbars,ylim=None,
                    info_text=False,path_for_output='../../results/graphics/')

# %%
# ***CHANGE THE FOLLOWING VARIABLES AS DESIRED***
source_name = 'rewo_cdi'
target_name = 'katom_cdi'
selected_estimator = ['rf']  # None means all! ['lr'] or ['xgb'] or ['lr','xgb']
selected_qs = ['lr_lsvc_rf_dt']  # None means all! ['lr_lsvc_rf_dt','random']
al_also = al_results   # None means only ATL Results are plotted. If al_also = al_results then also al results
quota = 100
n = 5
selected_weights = None
#awtl_results = awtl_results_dense
# ***********************************************

dut.plotAWTLResults(awtl_results,source_name,target_name,quota,candsets,candsets_super_results,n,
                    selected_estimator,al_also,selected_qs,selected_weights,errorbars=False,ylim=None,
                    info_text=False,path_for_output='../../results/graphics/')

# %%
# ***CHANGE THE FOLLOWING VARIABLES AS DESIRED***
source_name = 'rewo_cdi'
target_name = 'katom_cdi'
selected_estimator = ['rf']  # None means all! ['lr'] or ['xgb'] or ['lr','xgb']
selected_qs = ['lr_lsvc_rf_dt','random']  # None means all! ['lr_lsvc_rf_dt','random']
al_also = al_results   # None means only ATL Results are plotted. If al_also = al_results then also al results
quota = 100
n = 5
selected_weights = ['no_weighting']
#awtl_results = awtl_results_dense
# ***********************************************

dut.plotAWTLResults(awtl_results,source_name,target_name,quota,candsets,candsets_super_results,n,
                    selected_estimator,al_also,selected_qs,selected_weights,errorbars=False,ylim=(0.6,0.9),
                    info_text=False,path_for_output='../../results/graphics/')
